# %% [markdown]
# - Question 3  Import the required packages with their customary aliases as follows
# - Question 4  Use the `%matplotlib inline` magic command so that your plots show in the notebook _without_ having to                         call `plt.show()` every time.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
#  - Question 5  Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called                            `gdp_df`. Take a look at the first 6 rows.
#  - Notes: read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't  forget to put the file name at the end of the path + ".csv"

# %%
gdp_df = pd.read_csv (r'C:\Users\laure\Documents\NSS\Python\projects\gdp-and-internet-usage-LaurenDellaRusso\data\gdp_percapita2.csv')  
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN

# %% [markdown]
#  - Question 6  Repeat for the internet use dataset. Call this DataFrame `internet_df`.Take a look at the first six rows.
#  - Notes: Had parsing error row 4675 was bad so found code to skip so we could load file

# %%
internet_df = pd.read_csv (r'C:\Users\laure\Documents\NSS\Python\projects\gdp-and-internet-usage-LaurenDellaRusso\data\internet_use2.csv',error_bad_lines=False, engine ='python')
internet_df.head(6)
# Out:
# C:\Users\laure\AppData\Local\Temp\ipykernel_65420\3974461705.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   internet_df = pd.read_csv (r'C:\Users\laure\Documents\NSS\Python\projects\gdp-and-internet-usage-LaurenDellaRusso\data\internet_use2.csv',error_bad_lines=False, engine ='python')
# Skipping line 4675: ',' expected after '"'
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %% [markdown]
#  - Question 98  Look at the shape of each DataFrame - how many rows? How many columns?

# %%
gdp_df.shape
# Out:
# (6870, 4)

# %%
internet_df.shape
# Out:
# (4675, 4)

# %% [markdown]
#  - Question 6  Take a look at the datatypes for the columns in each DataFrame.

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                object
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                object
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
#  - Question 99  Take a look at the last 10 rows of each DataFrame in turn.
#        - Had to remove rows that had footnote data first

# %%
internet_df.drop(labels=range(4495,4675), axis=0, inplace = True)  #last row of actual data is 4496 - need to delete rows 4497-4688
internet_df
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 0        Afghanistan  2014  6.390000              NaN
# 1        Afghanistan  2013  5.900000              NaN
# 2        Afghanistan  2012  5.454545              NaN
# 3        Afghanistan  2011  5.000000              NaN
# 4        Afghanistan  2010  4.000000              NaN
# ...              ...   ...       ...              ...
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN
#
# [4495 rows x 4 columns]

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %%
gdp_df.drop(labels=[6868,6869], axis=0, inplace = True)  #last row of actual data is 6869 so we needed to drop 2 rows
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2019  2065.036398              NaN
# 1        Afghanistan  2018  2033.779002              NaN
# 2        Afghanistan  2017  2058.383832              NaN
# 3        Afghanistan  2016  2057.062164              NaN
# 4        Afghanistan  2015  2068.265904              NaN
# ...              ...   ...          ...              ...
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN
#
# [6868 rows x 4 columns]

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6858        Zimbabwe  1999  3600.849291              NaN
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %% [markdown]
#  - Question 7  Drop the `value footnotes` column from both DataFrames. Check that this worked as expected.

# %%
gdp_df.drop('Value Footnotes', axis=1, inplace=True)
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2019  2065.036398
# 1        Afghanistan  2018  2033.779002
# 2        Afghanistan  2017  2058.383832
# 3        Afghanistan  2016  2057.062164
# 4        Afghanistan  2015  2068.265904
# ...              ...   ...          ...
# 6863        Zimbabwe  1994  3263.934978
# 6864        Zimbabwe  1993  3033.504852
# 6865        Zimbabwe  1992  3054.889178
# 6866        Zimbabwe  1991  3426.598094
# 6867        Zimbabwe  1990  3324.348171
#
# [6868 rows x 3 columns]

# %%
internet_df.drop('Value Footnotes', axis=1, inplace=True)
internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
#  - Question 8  Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %% [markdown]
#  - Question 9  Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
#  - Question 10  Merge the two DataFrames to one. Merge **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`.

# %%
gdp_and_internet_use=pd.merge(internet_df, gdp_df, on = ['Country', 'Year'], how = 'outer')
gdp_and_internet_use
# Out:
#           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0     Afghanistan  2014            6.390000     2102.385234
# 1     Afghanistan  2013            5.900000     2116.465454
# 2     Afghanistan  2012            5.454545     2075.491747
# 3     Afghanistan  2011            5.000000     1904.559799
# 4     Afghanistan  2010            4.000000     1957.029338
# ...           ...   ...                 ...             ...
# 7900     Zimbabwe  2016                 NaN     2934.733650
# 7901     Zimbabwe  2015                 NaN     2958.209004
# 7902     Zimbabwe  1993                 NaN     3033.504852
# 7903     Zimbabwe  1992                 NaN     3054.889178
# 7904     Zimbabwe  1991                 NaN     3426.598094
#
# [7905 rows x 4 columns]

# %% [markdown]
#  - Question 11 Look at the first five rows of your new DataFrame to confirm it merged correctly.

# %%
gdp_and_internet_use.head(5)
# Out:
#        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0  Afghanistan  2014            6.390000     2102.385234
# 1  Afghanistan  2013            5.900000     2116.465454
# 2  Afghanistan  2012            5.454545     2075.491747
# 3  Afghanistan  2011            5.000000     1904.559799
# 4  Afghanistan  2010            4.000000     1957.029338

# %% [markdown]
#  - Question 12 Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use.tail(5)
# Out:
#        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 7900  Zimbabwe  2016                 NaN     2934.733650
# 7901  Zimbabwe  2015                 NaN     2958.209004
# 7902  Zimbabwe  1993                 NaN     3033.504852
# 7903  Zimbabwe  1992                 NaN     3054.889178
# 7904  Zimbabwe  1991                 NaN     3426.598094

# %% [markdown]
#  - Question 13 	Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
my_list = ['2004', '2009', '2014']   
new = gdp_and_internet_use.query("Year in @my_list")
new
# Out:
#                  Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0            Afghanistan  2014            6.390000     2102.385234
# 5            Afghanistan  2009            3.550000     1758.904043
# 10           Afghanistan  2004            0.105809     1200.278256
# 15               Albania  2014           60.100000    11623.866679
# 20               Albania  2009           41.200000    10346.864199
# ...                  ...   ...                 ...             ...
# 7843  West Bank and Gaza  2009                 NaN     5250.116075
# 7848  West Bank and Gaza  2004                 NaN     4485.525458
# 7864               World  2014                 NaN    15189.648507
# 7869               World  2009                 NaN    13396.524163
# 7874               World  2004                 NaN    12077.823821
#
# [830 rows x 4 columns]

# %% [markdown]
#  - Question 14 Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
year04_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == '2004')]
year04_df
# Out:
#                   Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 10            Afghanistan  2004            0.105809     1200.278256
# 25                Albania  2004            2.420388     7604.838002
# 46                Algeria  2004            4.634475    10058.435939
# 69                Andorra  2004           26.837954             NaN
# 88                 Angola  2004            0.464815     5593.241537
# ...                   ...   ...                 ...             ...
# 7698               Tuvalu  2004                 NaN     3336.952920
# 7761  Upper middle income  2004                 NaN     8567.061394
# 7818              Vietnam  2004                 NaN     3689.732423
# 7848   West Bank and Gaza  2004                 NaN     4485.525458
# 7874                World  2004                 NaN    12077.823821
#
# [276 rows x 4 columns]

# %%
year09_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == '2009')]
year09_df
# Out:
#                   Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 5             Afghanistan  2009                3.55     1758.904043
# 20                Albania  2009               41.20    10346.864199
# 41                Algeria  2009               11.23    10782.361398
# 64                Andorra  2009               78.53             NaN
# 83                 Angola  2009                6.00     7643.493749
# ...                   ...   ...                 ...             ...
# 7602           The Gambia  2009                 NaN     2283.183556
# 7756  Upper middle income  2009                 NaN    11212.934078
# 7813              Vietnam  2009                 NaN     4830.304958
# 7843   West Bank and Gaza  2009                 NaN     5250.116075
# 7869                World  2009                 NaN    13396.524163
#
# [277 rows x 4 columns]

# %%
year14_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == '2014')]
year14_df
# Out:
#                   Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 0             Afghanistan  2014                6.39     2102.385234
# 15                Albania  2014               60.10    11623.866679
# 36                Algeria  2014               18.09    11512.705405
# 59                Andorra  2014               95.90             NaN
# 78                 Angola  2014               21.26     8239.828837
# ...                   ...   ...                 ...             ...
# 7695               Tuvalu  2014                 NaN     3450.793169
# 7751  Upper middle income  2014                 NaN    14275.343977
# 7808              Vietnam  2014                 NaN     6098.489609
# 7838   West Bank and Gaza  2014                 NaN     5967.073437
# 7864                World  2014                 NaN    15189.648507
#
# [277 rows x 4 columns]

# %% [markdown]
#  - Question 15/17 Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending = False).head(1)
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1866  Iceland  2014               98.16      49652.1495

# %%
year04_df.sort_values(by = 'Internet_Users_Pct', ascending = False).head(1)
# Out:
#      Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 3835  Sweden  2004               83.89    44496.023401

# %%
year09_df.sort_values(by = 'Internet_Users_Pct', ascending = False).head(1)
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1871  Iceland  2009                93.0    48177.084123

# %% [markdown]
#  - Question 16/17 	Which country had the lowest percentage of internet users in 2014? What was the percentage?

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending = True).head(1)
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1065  Dem. People's Rep. of Korea  2014                 0.0             NaN

# %%
year04_df.sort_values(by = 'Internet_Users_Pct', ascending = True).head(1)
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1074  Dem. People's Rep. of Korea  2004                 0.0             NaN

# %%
year09_df.sort_values(by = 'Internet_Users_Pct', ascending = True).head(1)
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1069  Dem. People's Rep. of Korea  2009                 0.0             NaN

# %% [markdown]
#  - ##Question 18	Which country had the highest gdp per capita in 2014? What was the gdp per capita?##

# %%
year14_df.sort_values(by = 'GDP_Per_Capita', ascending = False).head(1)
# Out:
#                Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 6394  Macao SAR, China  2014                 NaN    156514.13385

# %% [markdown]
#  - ##Question 20  	Which country had the lowest gdp per capita in 2014? What was the gdp per capita?

# %%
year14_df.sort_values(by = 'GDP_Per_Capita', ascending = True).head(1)
# Out:
#                        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 4906  Central African Republic  2014                 NaN      822.610458

# %% [markdown]
#  - ##Question 21  	Create some scatterplots:
#     a.  2004 Percent Using the Internet vs GDP Per Capita
#     b.	2009 Percent Using the Internet vs GDP Per Capita
#     c.	2014 Percent Using the Internet vs GDP Per Capita

# %%
year04_df.plot.scatter(y = 'Internet_Users_Pct', x ='GDP_Per_Capita');

# %%
year09_df.plot.scatter(y = 'Internet_Users_Pct', x ='GDP_Per_Capita');

# %%
year14_df.plot.scatter(y = 'Internet_Users_Pct', x ='GDP_Per_Capita');

# %% [markdown]
#  - ##Question 22 	  Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.

# %% [markdown]
# As the years progress both GDP and Internet users increase

# %% [markdown]
#  - ##Question 23 Look at the distribution of gdp per capita values for 2014. Is it unimodal?   NO

# %%
year14_df['GDP_Per_Capita'].plot(kind='hist');

# %% [markdown]
#  - ##Question 24 Look at the distribution of Internet Use for 2014. Is it unimodal? NO

# %%
year14_df['Internet_Users_Pct'].plot(kind='hist');

# %% [markdown]
#  - ##Question 25  What are the top 5 countries in terms of internet use in 2014?

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending = False).head()
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1866  Iceland  2014               98.16    49652.149500
# 415   Bermuda  2014               96.80    77361.104881
# 3016   Norway  2014               96.30    62589.373548
# 1083  Denmark  2014               95.99    52214.537753
# 59    Andorra  2014               95.90             NaN

# %% [markdown]
#  - ##Question 26  Create a DataFrame called top_5_internet **from the combined DataFrame that has all three years _for the 5 countries that had the greatest 2014 internet usage_**. You should have 15 rows. Check that this is true.

# %%
my_list = ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra']   
new14 = year14_df.query("Country in @my_list")
new14
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 59    Andorra  2014               95.90             NaN
# 415   Bermuda  2014               96.80    77361.104881
# 1083  Denmark  2014               95.99    52214.537753
# 1866  Iceland  2014               98.16    49652.149500
# 3016   Norway  2014               96.30    62589.373548

# %%
my_list = ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra']   
new09 = year09_df.query("Country in @my_list")
new09
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 64    Andorra  2009               78.53             NaN
# 420   Bermuda  2009               83.25    89961.982744
# 1088  Denmark  2009               86.84    50274.075696
# 1871  Iceland  2009               93.00    48177.084123
# 3021   Norway  2009               92.08    61886.564498

# %%
my_list = ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra']   
new04 = year04_df.query("Country in @my_list")
new04
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 69    Andorra  2004           26.837954             NaN
# 425   Bermuda  2004           60.990867    90195.811033
# 1093  Denmark  2004           80.930000    50607.628971
# 1876  Iceland  2004           83.880000    45145.545658
# 3026   Norway  2004           77.690000    60893.410993

# %%
df_top_5_internet = pd.concat([new04, new09, new14])  
df_top_5_internet
# Out:
#       Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 69    Andorra  2004           26.837954             NaN
# 425   Bermuda  2004           60.990867    90195.811033
# 1093  Denmark  2004           80.930000    50607.628971
# 1876  Iceland  2004           83.880000    45145.545658
# 3026   Norway  2004           77.690000    60893.410993
# 64    Andorra  2009           78.530000             NaN
# 420   Bermuda  2009           83.250000    89961.982744
# 1088  Denmark  2009           86.840000    50274.075696
# 1871  Iceland  2009           93.000000    48177.084123
# 3021   Norway  2009           92.080000    61886.564498
# 59    Andorra  2014           95.900000             NaN
# 415   Bermuda  2014           96.800000    77361.104881
# 1083  Denmark  2014           95.990000    52214.537753
# 1866  Iceland  2014           98.160000    49652.149500
# 3016   Norway  2014           96.300000    62589.373548

# %% [markdown]
#  - ##Question 27 Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014?
#
#
#  - ##Answer: Andorra##

# %%
############# Main Section         #############
# Form a facetgrid using columns 
graph = sns.FacetGrid(df_top_5_internet, col ='Country', hue = 'Year')
# map the above form facetgrid with some attributes
graph.map_dataframe(plt.scatter, 'Year', 'Internet_Users_Pct', edgecolor ="w").add_legend();

# %% [markdown]
#  - ##Question 28	Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use?
#
#  ##ANSWER: Dem. People's Rep. of Korea

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending = True).head()
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 1065  Dem. People's Rep. of Korea  2014                0.00             NaN
# 1256                      Eritrea  2014                0.99             NaN
# 4019                  Timor-Leste  2014                1.14     3264.568070
# 623                       Burundi  2014                1.38      886.235777
# 3648                      Somalia  2014                1.63             NaN

# %%
my_list = ["Dem. People's Rep. of Korea", 'Eritrea', 'Timor-Leste', 'Burundi', 'Somalia']   
new14low = year14_df.query("Country in @my_list")
new14low
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 623                       Burundi  2014                1.38      886.235777
# 1065  Dem. People's Rep. of Korea  2014                0.00             NaN
# 1256                      Eritrea  2014                0.99             NaN
# 3648                      Somalia  2014                1.63             NaN
# 4019                  Timor-Leste  2014                1.14     3264.568070

# %%
my_list = ["Dem. People's Rep. of Korea", 'Eritrea', 'Timor-Leste', 'Burundi', 'Somalia']   
new09low = year09_df.query("Country in @my_list")
new09low
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 628                       Burundi  2009            0.900000      831.564131
# 1069  Dem. People's Rep. of Korea  2009            0.000000             NaN
# 1261                      Eritrea  2009            0.540000             NaN
# 3652                      Somalia  2009            1.160611             NaN
# 4024                  Timor-Leste  2009            0.185252     2724.770973

# %%
my_list = ["Dem. People's Rep. of Korea", 'Eritrea', 'Timor-Leste', 'Burundi', 'Somalia']   
new04low = year04_df.query("Country in @my_list")
new04low
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 633                       Burundi  2004            0.349060      817.460585
# 1074  Dem. People's Rep. of Korea  2004            0.000000             NaN
# 3657                      Somalia  2004            1.053455             NaN
# 7627                  Timor-Leste  2004                 NaN     2258.608056

# %%
df_low_5_internet = pd.concat([new04low, new09low, new14low])  
df_low_5_internet
# Out:
#                           Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 633                       Burundi  2004            0.349060      817.460585
# 1074  Dem. People's Rep. of Korea  2004            0.000000             NaN
# 3657                      Somalia  2004            1.053455             NaN
# 7627                  Timor-Leste  2004                 NaN     2258.608056
# 628                       Burundi  2009            0.900000      831.564131
# 1069  Dem. People's Rep. of Korea  2009            0.000000             NaN
# 1261                      Eritrea  2009            0.540000             NaN
# 3652                      Somalia  2009            1.160611             NaN
# 4024                  Timor-Leste  2009            0.185252     2724.770973
# 623                       Burundi  2014            1.380000      886.235777
# 1065  Dem. People's Rep. of Korea  2014            0.000000             NaN
# ...

# %%
############# Main Section         #############
# Form a facetgrid using columns 
graph = sns.FacetGrid(df_low_5_internet, col ='Country', hue = 'Year')
# map the above form facetgrid with some attributes
graph.map_dataframe(plt.scatter, 'Year', 'Internet_Users_Pct', edgecolor ="w").add_legend();

# %% [markdown]
# - ##Question 29 Find the top 5 countries for 2014 in terms of GDP per capita; create a DataFrame to look at 10-year trends (use 2004, 2009, 2014 to look at the 10-year trend) in gdp per capita for the 5 countries with the highest 2014 GDP per capita. Use a seaborn facet grid for this.

# %%
year14_df.sort_values(by = 'GDP_Per_Capita', ascending = False).head()
# Out:
#                Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 6394  Macao SAR, China  2014                 NaN   156514.133850
# 2407        Luxembourg  2014               94.67   108760.916030
# 3279             Qatar  2014               91.49    95578.416973
# 3556         Singapore  2014               82.00    87808.663157
# 415            Bermuda  2014               96.80    77361.104881

# %%
gdp_list = ['Macao SAR, China', 'Luxembourg', 'Qatar', 'Singapore', 'Bermuda']   
gdpnew14 = year14_df.query("Country in @gdp_list")
gdpnew14
# Out:
#                Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 415            Bermuda  2014               96.80    77361.104881
# 2407        Luxembourg  2014               94.67   108760.916030
# 3279             Qatar  2014               91.49    95578.416973
# 3556         Singapore  2014               82.00    87808.663157
# 6394  Macao SAR, China  2014                 NaN   156514.133850

# %%
gdp_list = ['Macao SAR, China', 'Luxembourg', 'Qatar', 'Singapore', 'Bermuda']   
gdpnew09 = year09_df.query("Country in @gdp_list")
gdpnew09
# Out:
#                Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 420            Bermuda  2009               83.25    89961.982744
# 2412        Luxembourg  2009               87.31   104932.811953
# 3284             Qatar  2009               53.10    89954.519993
# 3561         Singapore  2009               69.00    69466.581746
# 6399  Macao SAR, China  2009                 NaN    95939.340822

# %%
gdp_list = ['Macao SAR, China', 'Luxembourg', 'Qatar', 'Singapore', 'Bermuda']   
gdpnew04 = year04_df.query("Country in @gdp_list")
gdpnew04
# Out:
#                Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 425            Bermuda  2004           60.990867    90195.811033
# 2417        Luxembourg  2004           65.880000   102708.212547
# 3289             Qatar  2004           20.701648    93748.301216
# 3566         Singapore  2004           62.000000    63901.716368
# 6404  Macao SAR, China  2004                 NaN    72944.409424

# %%
df_hi_5_gdp = pd.concat([gdpnew04, gdpnew09, gdpnew14 ])  
df_hi_5_gdp
# Out:
#                Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 425            Bermuda  2004           60.990867    90195.811033
# 2417        Luxembourg  2004           65.880000   102708.212547
# 3289             Qatar  2004           20.701648    93748.301216
# 3566         Singapore  2004           62.000000    63901.716368
# 6404  Macao SAR, China  2004                 NaN    72944.409424
# 420            Bermuda  2009           83.250000    89961.982744
# 2412        Luxembourg  2009           87.310000   104932.811953
# 3284             Qatar  2009           53.100000    89954.519993
# 3561         Singapore  2009           69.000000    69466.581746
# 6399  Macao SAR, China  2009                 NaN    95939.340822
# 415            Bermuda  2014           96.800000    77361.104881
# 2407        Luxembourg  2014           94.670000   108760.916030
# 3279             Qatar  2014           91.490000    95578.416973
# ...

# %%
############# Main Section         #############
# Form a facetgrid using columns 
graph = sns.FacetGrid(df_hi_5_gdp, col ='Country', hue = 'Year')
# map the above form facetgrid with some attributes
graph.map_dataframe(plt.scatter, 'Year', 'GDP_Per_Capita', edgecolor ="w").add_legend();

# %% [markdown]
#  - ##Question 96  Repeat this one more time to look at 10-year trend for the 5 countries for 2014 with the lowest GDP per capita.

# %%
year14_df.sort_values(by = 'GDP_Per_Capita', ascending = True).head()
# Out:
#                        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 4906  Central African Republic  2014                 NaN      822.610458
# 623                    Burundi  2014                1.38      886.235777
# 2473                    Malawi  2014                5.83     1027.208496
# 5063           Dem. Rep. Congo  2014                 NaN     1029.790785
# 2975                     Niger  2014                1.95     1127.615541

# %%
gdp_low = ['Central African Republic', 'Burundi', 'Malawi', 'Dem. Rep. Congo', 'Niger']   
gdplow14 = year14_df.query("Country in @gdp_low")
gdplow14
# Out:
#                        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 623                    Burundi  2014                1.38      886.235777
# 2473                    Malawi  2014                5.83     1027.208496
# 2975                     Niger  2014                1.95     1127.615541
# 4906  Central African Republic  2014                 NaN      822.610458
# 5063           Dem. Rep. Congo  2014                 NaN     1029.790785

# %%
gdp_low = ['Central African Republic', 'Burundi', 'Malawi', 'Dem. Rep. Congo', 'Niger']   
gdplow09 = year09_df.query("Country in @gdp_low")
gdplow09
# Out:
#                        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 628                    Burundi  2009                0.90      831.564131
# 2478                    Malawi  2009                1.07      932.867635
# 2980                     Niger  2009                0.76      992.409977
# 4911  Central African Republic  2009                 NaN     1161.189475
# 5068           Dem. Rep. Congo  2009                 NaN      835.611696

# %%
gdp_low = ['Central African Republic', 'Burundi', 'Malawi', 'Dem. Rep. Congo', 'Niger']   
gdplow04 = year04_df.query("Country in @gdp_low")
gdplow04
# Out:
#                        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 633                    Burundi  2004            0.349060      817.460585
# 2483                    Malawi  2004            0.347505      775.346132
# 2985                     Niger  2004            0.189934      929.883920
# 4916  Central African Republic  2004                 NaN     1037.846766
# 5073           Dem. Rep. Congo  2004                 NaN      757.685942

# %%
df_low_5_gdp = pd.concat([gdplow04, gdplow09, gdplow14 ])  
df_low_5_gdp
# Out:
#                        Country  Year  Internet_Users_Pct  GDP_Per_Capita
# 633                    Burundi  2004            0.349060      817.460585
# 2483                    Malawi  2004            0.347505      775.346132
# 2985                     Niger  2004            0.189934      929.883920
# 4916  Central African Republic  2004                 NaN     1037.846766
# 5073           Dem. Rep. Congo  2004                 NaN      757.685942
# 628                    Burundi  2009            0.900000      831.564131
# 2478                    Malawi  2009            1.070000      932.867635
# 2980                     Niger  2009            0.760000      992.409977
# 4911  Central African Republic  2009                 NaN     1161.189475
# 5068           Dem. Rep. Congo  2009                 NaN      835.611696
# 623                    Burundi  2014            1.380000      886.235777
# 2473                    Malawi  2014            5.830000     1027.208496
# ...

# %%
############# Main Section         #############
# Form a facetgrid using columns 
graph = sns.FacetGrid(df_low_5_gdp, col ='Country', hue = 'Year')
# map the above form facetgrid with some attributes
graph.map_dataframe(plt.scatter, 'Year', 'GDP_Per_Capita', edgecolor ="w").add_legend();

# %% [markdown]
#  - ##Question 30  Is there anything surprising or unusual in any of these plots? Searching on the internet, can you find any possible explanations for unusual findings?
#
#  - ANSWER
#  - Dem. People's Rep. of Korea has 0 Internet Usage for all 3 years. Found out that they do not allow regular citizens to access the internet. It is primarily used for govenment entities only.
#  - As Internet Use Increases so does GDP
